# %% [markdown]
# <a href="https://colab.research.google.com/github/MonseMoreno/ArteDeLaAnalitica/blob/main/ArteDeLaAnal%C3%ADtica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Vamos a importar el archivo y leer los contenidos.
import json

# Lectura del archivo
with open('credenciales.json', 'r') as myfile:
    data = myfile.read()

# Leer el formato del archivo
obj = json.loads(data)

# Vamos a guardar los datos en estas variables
GIT_USERNAME = obj['user']

# token
GIT_TOKEN = obj['token']

# Repo
GIT_REPO = obj['repo']

# Creamos la ruta al repositorio de nuestra cuenta
GIT_PATH = "https://" + GIT_USERNAME + ":" + GIT_TOKEN + "@github.com/" +\
            GIT_USERNAME + "/" + GIT_REPO + ".git"

# %%
# Vamos a imprimir el GIT_PATH para ver la estructura
GIT_PATH
# Out:
# 'https://MonseMoreno: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@github.com/MonseMoreno/ArteDeLaAnalitica.git'

# %%
# !git clone https://github.com/MonseMoreno/ArteDeLaAnalitica.git
# Out:
# Cloning into 'ArteDeLaAnalitica'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# %ls
# Out:
# ArteDeLaAnalitica/  credenciales.json  sample_data/

# %%
# %cd ArteDeLaAnalitica/
# Out:
# /content/ArteDeLaAnalitica

# %%
# %ls
# Out:
# README.md

# %%
# !git remote -v
# Out:
# origin	https://github.com/MonseMoreno/ArteDeLaAnalitica.git (fetch)
# origin	https://github.com/MonseMoreno/ArteDeLaAnalitica.git (push)

# %%
# !git remote rename origin curso_fuente

# %%
# !git remote add origin "{GIT_PATH}"

# %%
# !git remote -v
# Out:
# curso_fuente	https://github.com/MonseMoreno/ArteDeLaAnalitica.git (fetch)
# curso_fuente	https://github.com/MonseMoreno/ArteDeLaAnalitica.git (push)
# origin	https://MonseMoreno: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@github.com/MonseMoreno/ArteDeLaAnalitica.git (fetch)
# origin	https://MonseMoreno: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@github.com/MonseMoreno/ArteDeLaAnalitica.git (push)

# %%
# !git config --global user.email "a01276775@tec.mx"

# %%
# !git config --global user.name "Monse Moreno"

# %%
# !echo "Cambios en README - main" >> README.m

# %%
# !git add .

# %%
# !git commit -m "Cambios README"
# Out:
# [main f04a1e5] Cambios README
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.m

# %%
# !git push origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 297 bytes | 297.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/MonseMoreno/ArteDeLaAnalitica.git
#    687df09..f04a1e5  main -> main

# %%
# !git checkout -b "Dev"
# Out:
# Switched to a new branch 'Dev'

# %%
# !echo "Cambios en README - main" >> README.m

# %%
# !git commit -am "Cambios readme en nueva rama DEV"
# Out:
# [Dev 2d81bf2] Cambios readme en nueva rama DEV
#  1 file changed, 1 insertion(+)

# %%
# !git push --set-upstream origin Dev
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 309 bytes | 309.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'Dev' on GitHub by visiting:
# remote:      https://github.com/MonseMoreno/ArteDeLaAnalitica/pull/new/Dev
# remote:
# To https://github.com/MonseMoreno/ArteDeLaAnalitica.git
#  * [new branch]      Dev -> Dev
# Branch 'Dev' set up to track remote branch 'Dev' from 'origin'.

# %% [markdown]
# #**Actividad librería Pandas**

# %% [markdown]
# nombre: Monserrat Karime Moreno Casas

# %% [markdown]
# matricula: A01276775

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
#Implementa una función que despliegue el primer renglon de un DataFrame.

def the_first():
  return df.head(1)

the_first()
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %%
#Implementa una función que regrese el número de registros en el DataFrame.
def row_number():
  return df.shape

row_number()
# Out:
# (7787, 12)

# %%
#Implementa una función que despliega las películas con un release_year determinado.
def released_year(year):

  df_mask=df['release_year'] == year
  return df[df_mask]

year_query = 2020
released_year(year_query)
# Out:
#      show_id     type                                title           director  \
# 0         s1  TV Show                                   3%                NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
# 26       s27  TV Show                             (Un)Well                NaN
# 27       s28    Movie                               #Alive             Cho Il
# 29       s30  TV Show                             #blackAF                NaN
# ...      ...      ...                                  ...                ...
# 7725   s7726  TV Show                      You Cannot Hide                NaN
# 7734   s7735    Movie                      You've Got This  Salvador Espinosa
# 7738   s7739  TV Show                      Young Wallander                NaN
# 7741   s7742    Movie            Your Name Engraved Herein      Liu Kuang-hui
# 7744   s7745    Movie          Yours Sincerely, Kanan Gill       Neville Shah
#
# ...

# %%
#Implementa una función que despliegue las películas que son de un país determinado.
def origin_country(country):

   df_mask=df['country'] == country
   return df[df_mask]


country_query = 'Mexico'
origin_country(country_query)
# Out:
#      show_id     type                                           title  \
# 1         s2    Movie                                            7:19
# 12       s13  TV Show                                            1994
# 292     s293    Movie                             Acapulco La vida va
# 370     s371    Movie                  Alan Saldaña: Mi vida de pobre
# 378     s379    Movie  Alex Fernández: The Best Comedian in the World
# ...      ...      ...                                             ...
# 7698   s7699  TV Show                                          Yankee
# 7725   s7726  TV Show                                 You Cannot Hide
# 7734   s7735    Movie                                 You've Got This
# 7773   s7774    Movie                                  Zoé: Panoramas
# 7779   s7780  TV Show                                       Zona Rosa
#
#                                    director  \
# 1                         Jorge Michel Grau
# ...

# %%
#Crea un nuevo DataFrame que sólo contenga las columnas type, title, country y release_year.

df2 = pd.DataFrame({
                  'tipo' : df['type'],
                  'title' : df['title'],
                  'country' : df['country'],
                  'release_year': df['release_year'] 
})

df2
# Out:
#          tipo                                    title  \
# 0     TV Show                                       3%
# 1       Movie                                     7:19
# 2       Movie                                    23:59
# 3       Movie                                        9
# 4       Movie                                       21
# ...       ...                                      ...
# 7782    Movie                                     Zozo
# 7783    Movie                                   Zubaan
# 7784    Movie                        Zulu Man in Japan
# 7785  TV Show                    Zumbo's Just Desserts
# 7786    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                 country  release_year
# 0                                                Brazil          2020
# 1                                                Mexico          2016
# 2                                             Singapore          2011
# ...

# %%
#Despliega, cuantos tipos de producciones (type) se hicieron por país determinado (country). 
def producciones(country):

   df_mask=df['country'] == country
   resultado = df[df['country'] == country]['type'].count
   return resultado



country_query = 'Mexico'
producciones(country_query)
# Out:
# <bound method Series.count of 1         Movie
# 12      TV Show
# 292       Movie
# 370       Movie
# 378       Movie
#          ...
# 7698    TV Show
# 7725    TV Show
# 7734      Movie
# 7773      Movie
# 7779    TV Show
# Name: type, Length: 100, dtype: object>

# %% [markdown]
# #**9. Implementa la función que genera el cuadrado de un número.**

# %%
def square(x):
  square = pow(x, 2)
  return square


n = 6
square(6)
# Out:
# 36

# %%
df2 = pd.DataFrame({'A': [1, 2, 3, 5, 6], 'B': [10, 20, 30, 40, 50]})
df2
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  5  40
# 4  6  50

# %%
df2.apply(lambda x: x**2)
# Out:
#     A     B
# 0   1   100
# 1   4   400
# 2   9   900
# 3  25  1600
# 4  36  2500
